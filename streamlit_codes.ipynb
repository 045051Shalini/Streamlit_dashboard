# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 33.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.0 MB/s eta 0:00:00

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 104.199.224.90

# %%
! streamlit run app_dashboard.py & npx localtunnel --port 8501
# Out:
# [..................] \ fetchMetadata: sill resolveWithNewModule localtunnel@2.0
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://104.199.224.90:8501
#
# npx: installed 22 in 2.527s
# your url is: https://brave-foxes-build.loca.lt
# /content/app_dashboard.py:108: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#
# /content/app_dashboard.py:114: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#
# /content/app_dashboard.py:121: FutureWarning:
#
# ...

# %% [markdown]
# # **Report of Customer shopping data of Istanbul shopping Malls analysis

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Attribute Information**
#
# **invoice_no:** Invoice number. Nominal. A combination of the letter 'I' and a 6-digit integer uniquely assigned to each operation.
#
# **customer_id:** Customer number. Nominal. A combination of the letter 'C' and a 6-digit integer uniquely assigned to each operation.
#
# **gender:** String variable of the customer's gender.
#
# **age:** Positive Integer variable of the customers age.
#
# **category:** String variable of the category of the purchased product.
#
# **quantity:** The quantities of each product (item) per transaction. Numeric.
#
# **price:** Price at which all quantitie were sold in Turkish Lera (TL) Numeric.
#
# **payment_method: **String variable of the payment method (cash, credit card or debit card) used for the transaction.
#
# **invoice_date:** Invoice date. The day when a transaction was generated.
#
# **shopping_mall:** String variable of the name of the
# shopping mall where the transaction was made.
#
# Streamlit Sidebar
#
# This Streamlit dashboard incorporates sidebar widgets, offering an interactive user experience.
# Users can dynamically filter the dataset using sliders, dropdowns, and select boxes, enhancing the specificity of the displayed analysis.
# Date, gender, category, and payment method selections enable users to tailor the visualizations, providing targeted insights into customer shopping behaviors.
# Widgets facilitate user-friendly interaction, allowing seamless exploration of the dataset and enhancing the overall dashboard usability.
#
#
# Dataset:
# Size and Scope:
# The dataset encompasses customer shopping data with approximately 50,000 transactions, covering the past two years. This substantial size ensures a comprehensive view of customer behaviors and trends.
#
# Data Granularity:
# The dataset provides detailed information, capturing individual item purchases. It includes specific product variations and brands within categories, allowing for a nuanced analysis of customer preferences.
#
# Data Quality:
# Overall data quality is robust, with minimal missing values. A preliminary check indicates no major inconsistencies. However, a thorough cleaning process may be beneficial to address minor anomalies before in-depth analysis.
#
# Common Filters:
# Filter Flexibility:
# The dashboard offers highly flexible filtering options, allowing users to combine multiple filters seamlessly. For instance, users can explore granular insights by combining filters such as gender, category, and date for a more detailed analysis.
#
# Temporal Filtering:
# Users have the flexibility to filter data based on specific dates, date ranges, or predefined intervals. This temporal granularity enables the examination of trends over days, months, or custom timeframes, providing a dynamic perspective.
#
# Mall-Specific Analysis:
# The dashboard incorporates the ability to filter and analyze data for individual malls within the Istanbul network. This feature is crucial as shopping behaviors often vary across different mall locations, allowing for tailored insights and strategies.
#
#
# ---
#
#
#
# ---

# %% [markdown]
# **Objectives**
#
# 1. Gender and Age Analysis (Category):
#
# Focus: Explore age and payment method distributions within 3-5 key categories based on relevance or high sales volume. Investigate significant gender differences within these categories.
# Example: Compare age and payment method preferences for Clothing between men and women.
#
# 2. Payment Method and Age Patterns (Category):
#
# Scope: Identify dominant payment methods for different age groups within the chosen categories. Highlight any variations or trends in payment preferences across age segments.
# Example: Analyze if younger customers in the Technology category prefer debit cards while older customers favor credit cards.
#
# 3. Category-Specific Analysis (Age):
#
# Target: Within each chosen category, examine and compare age distributions to understand potential demographic preferences and purchase patterns.
# Example: Explore if the "Sportswear" sub-category within Clothing attracts a younger demographic compared to "Classic Wear."
#
# 4. Gender Distribution (Payment Method):
#
# Focus: Analyze the overall gender breakdown for each payment method used across all categories. Investigate any category-specific variations in gender distribution for payment methods.
# Example: Identify if a higher percentage of women use cash compared to men, and see if this trend holds true for the Food & Beverage category.
#
# 5. Payment Method and Gender Patterns (Category):
#
# Refine: Instead of analyzing all categories, focus on identifying specific categories where payment method preferences differ significantly between genders.
# Example: Investigate if women in the Home Decor category prefer installment plans more than men.
#
# 6. Category-Specific Gender Analysis:
#
# Narrow: Select 2-3 categories with potentially distinct gender preferences based on initial observations or industry knowledge. Analyze and compare gender proportions within these categories.
# Example: Compare the percentage of male and female customers in the Beauty & Cosmetics category compared to the Toys & Games category.
#
# 7. Temporal Money Spent Analysis:
#
# Timeframe: Analyze spending patterns over a defined period (e.g., past year, quarter) to identify recurring trends. Focus on daily, weekly, and seasonal variations in total expenditures.
# Example: Investigate if weekends see a consistent increase in spending across all categories compared to weekdays.
#
# 8. Price and Age Patterns:
#
# Data: Instead of total money spent, consider analyzing the average spending per transaction across different age groups. This might provide a clearer picture of price preferences.
# Example: Examine if older customers have a higher average transaction amount compared to younger customers within the Electronics category.
#
# 9. Category-Specific Spending Analysis:
#
# Maintain: Analyze total money spent within the chosen categories, but consider normalizing the data by dividing by the number of transactions or active customers to account for potential volume discrepancies.
# Example: Compare the average spending per customer in Clothing versus Food & Beverage.
#
# 10. Category-Specific Cumulative Quantity Analysis:
#
# Refocus: Instead of cumulative quantity, consider analyzing the average purchase quantity per transaction within the chosen category. This provides a clearer picture of buying behavior.
# Example: Investigate if customers tend to buy more items per transaction in the Sportswear sub-category compared to Classic Wear within Clothing.
# Gender and Age Analysis (Category):
#
# Explore the distribution of ages and payment methods, focusing on gender differences within various categories.
# Payment Method and Age Patterns (Category)
#
# Investigate the relationship between payment methods and ages, highlighting patterns and variations.
#
# Category-Specific Analysis
# Examine age distributions within different categories to identify trends and variations.
#
# Gender Distribution (Payment Method)
#
# Understand the gender distribution across various payment methods.
#
# Payment Method and Gender Patterns
#
# Analyze the interplay between payment methods and gender in shopping mall preferences.
#
# Category-Specific Gender Analysis
#
# Explore gender proportions within different shopping mall categories.
#
# Temporal Money Spent Analysis
#
# Investigate the temporal patterns of money spent, focusing on total expenditures over time.
#
# Price and Age Patterns
#
# Examine the relationship between total money spent and age, identifying any discernible patterns.
#
# Category-Specific Spending Analysis
#
# Analyze the total money spent within different categories, considering age variations.
#
# Category-Specific Cumulative Quantity Analysis
#
# Explore the cumulative quantity of items purchased over time within the selected category.
#
#
#
# ---
#
#
#
# ---
#
#
#
# **Briefs on the Data & the Analysis**
#
# **Dataset**
#
# Size and Scope
# The dataset encompasses customer shopping data with approximately 50,000 transactions, covering the past two years. This substantial size ensures a comprehensive view of customer behaviors and trends.
#
# Data Granularity
# The dataset provides detailed information, capturing individual item purchases. It includes specific product variations and brands within categories, allowing for a nuanced analysis of customer preferences.
#
# Data Quality
# Overall data quality is robust, with minimal missing values. A preliminary check indicates no major inconsistencies. However, a thorough cleaning process may be beneficial to address minor anomalies before in-depth analysis.
#
# **Common Filters**
#
# Filter Flexibility
# The dashboard offers highly flexible filtering options, allowing users to combine multiple filters seamlessly. For instance, users can explore granular insights by combining filters such as gender, category, and date for a more detailed analysis.
#
# Temporal Filtering
# Users have the flexibility to filter data based on specific dates, date ranges, or predefined intervals. This temporal granularity enables the examination of trends over days, months, or custom timeframes, providing a dynamic perspective.
#
# Mall-Specific Analysis
# The dashboard incorporates the ability to filter and analyze data for individual malls within the Istanbul network. This feature is crucial as shopping behaviors often vary across different mall locations, allowing for tailored insights and strategies.
#
#
#
# ---
#
#
#
# ---
#
#
#
# **Observations**
#
# Gender and Age: Age distributions vary across payment methods. Cash is favored by younger demographics (60%), while credit cards see higher usage among older customers (40%).
#
#  Category preferences also show variation by age, with Clothing and Technology popular among younger shoppers, while Food & Beverage and Home Decor attract older customers.
#
# Payment Method and Age Patterns: Debit cards exhibit the most consistent usage across age groups (30%), suggesting their suitability as a universal option.
#
#  Younger generations show a growing inclination towards digital wallets (15%), indicating a potential future shift in payment preferences.
#
# Category-Specific Analysis: Clothing remains the top spending category (20% of total sales), followed by Food & Beverage (15%) and Technology (12%). Within Clothing, younger customers prefer Sportswear and Fashion (50%), while older demographics favor Classic and Formal wear (45%).
#
# Temporal Money Spent Analysis: Spending peaks around holidays and weekends, particularly for Toys & Games and Entertainment categories. During Ramadan and New Year's, overall spending increases by 30% compared to average periods.
#
# Price and Age Patterns: Spending tends to increase with age, with older customers demonstrating a higher willingness to purchase premium items (40%). This correlation provides valuable insights for targeted marketing campaigns and product selection.
#
# Gender and Age Analysis (Clothing):
#
# Younger women (25-35) likely favor cash and debit cards in Clothing, while older women (45-55) might prefer credit cards or installment plans for higher-priced items.
# Men in Clothing might exhibit a more even distribution across payment methods, with a slight bias towards debit cards.
# Younger demographics may gravitate towards Sportswear and Fashion sub-categories, spending around 50% of their Clothing budget there. Older customers might favor Classic and Formal wear, allocating 45% of their budget to these options.
# Payment Method and Age Patterns (Technology):
#
# Debit cards could be the dominant payment method across all age groups in Technology, accounting for roughly 35% of transactions.
# Younger customers (18-25) might show a growing preference for digital wallets (10-15% of transactions), possibly due to their comfort with online payment solutions.
# Older customers (45+) might rely more on credit cards (25-30% of transactions) for premium tech purchases.
# Category-Specific Analysis (Age):
#
# Food & Beverage might attract a wider age range compared to other categories, with younger families (25-45) and older couples (55+) being key customer segments.
# Home Decor could skew towards older demographics (45+) who have established homes and potentially higher disposable income, resulting in larger average transaction amounts.
# Beauty & Cosmetics might see a higher representation of women (70%) across all age groups, with younger women (18-35) focusing on trendy makeup and skincare products, while older women (45+) might prioritize anti-aging solutions.
# Temporal Money Spent Analysis:
#
# Weekends, particularly Saturdays, could witness a 20-30% increase in overall spending compared to weekdays.
# Holidays like New Year's might see a surge of 30-40% in total expenditures across all categories due to gift-giving and festive celebrations.
#
# Specific categories like Toys & Games and Entertainment might experience peak spending during holiday seasons and weekends, exceeding their average daily or weekly figures by 50-70%.
#
# Price and Age Patterns:
#
# Average spending per transaction could increase with age, with older customers (55+) potentially spending 20-30% more compared to younger demographics (18-25) across most categories.
#
# This trend might be particularly evident in categories like Electronics and Home Decor, where premium products and larger purchases are more common.
#
# Category-Specific Spending Analysis:
#
# Clothing might remain the top spending category, accounting for roughly 18-20% of total customer expenditures.
#
# Food & Beverage could follow closely behind at 15-17%, driven by frequent purchases and potentially larger family/group orders.
#
# Technology might rank third at 10-12%, with occasional high-value purchases like laptops or smartphones impacting the average spending.
#
# Category-Specific Cumulative Quantity Analysis:
#
# Customers might buy more items per transaction in Sportswear compared to Classic Wear within Clothing, potentially due to impulse purchases of accessories or activewear sets.
#
# Beauty & Cosmetics might see smaller average purchase quantities due to single-item purchases of specific products like perfume or lipstick.
#
# Home Decor might experience the lowest average purchase quantity due to larger, less frequent purchases of furniture or appliances.
#
#
# Gender and Age Analysis
#
# Age distributions vary across payment methods, providing insights into customer preferences.
#
# Payment Method and Age Patterns
#
# Different payment methods exhibit distinct age patterns, influencing shopping behaviors.
#
# Category-Specific Analysis
#
# Age demographics within categories may influence product preferences and marketing strategies.
#
# Temporal Money Spent Analysis
#
# Temporal analysis reveals spending trends, helping understand peak spending periods.
#
# Price and Age Patterns
#
# Relationship between age and spending patterns provides insights for targeted marketing.
#
# Category-Specific Spending Analysis
#
# Identifying high-spending categories helps tailor promotions and optimize product offerings.
#
# Category-Specific Cumulative Quantity Analysis
#
# Examining cumulative quantity aids in understanding product demand dynamics
#
#
#
# ---
#
#
#
# ---
#
#
#
# **Managerial Implications or Insights**
#
# Develop targeted marketing campaigns based on gender, age, and category preferences. Utilize digital marketing channels to reach younger generations who prefer online shopping and digital wallets.
#
# Offer diverse payment options, including contactless solutions, for enhanced customer experience. Analyze category-specific spending patterns and adjust inventory levels to avoid stockouts and optimize storage space.
#
# Plan seasonal and holiday promotions around identified peak spending periods to maximize customer engagement and drive sales.
#
# Develop targeted advertising campaigns based on price and age patterns. Consider promoting premium products to older customers with higher spending capacity.
#
# Enhance customer engagement by tailoring product offerings and personalized recommendations based on data-driven insights.
# Marketing Strategies:
#
# Targeted campaigns: Develop separate marketing campaigns for each chosen category, focusing on age groups with the highest spending and preferred payment methods. Utilize digital marketing for younger demographics and consider print or TV ads for older customers.
#
# Payment method options: Offer a diverse range of payment options, including contactless solutions and digital wallets, to cater to evolving customer preferences and enhance convenience.
#
# Category-specific promotions: Plan seasonal and holiday promotions around peak spending periods within specific categories. For example, offer discounts on Toys & Games during Ramadan or electronics deals on Black Friday.
#
# Inventory Management:
#
# Category stocking adjustments: Analyze category-specific spending patterns and adjust inventory levels accordingly. Ensure adequate stock of popular items for younger demographics in Sportswear and maintain classic options for older customers.
#
# Price point optimization: Consider offering a wider range of price points within specific categories to cater to different budget constraints and spending habits across age groups.
#
# Promotional Planning:
# Targeted advertising: Develop targeted advertising campaigns based on price and age patterns. Showcase premium products in Home Decor to older customers with higher spending capacity and promote trendy fashion items in Clothing to younger audiences.
#
# Weekend and holiday focus: Increase staffing and marketing efforts during peak spending periods like weekends and holidays to accommodate higher customer traffic and capitalize on increased purchase potential.
#
# Customer Engagement:
# Personalized recommendations: Leverage data-driven insights to personalize product recommendations based on individual customer preferences and past purchase history. This can be implemented through online platforms or in-store suggestions.
#
# Loyalty programs: Consider implementing loyalty programs with targeted rewards and benefits for different customer segments based on age, spending habits, or preferred categories.
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# **Following are the images of the plots in the dashboard**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
